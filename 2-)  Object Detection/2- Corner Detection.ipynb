# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#resmi içe aktar
img = cv2.imread("sudoku.png",0)
img = np.float32(img)
print(img.shape)
plt.figure(),plt.imshow(img,cmap="gray"),plt.axis("off")
# Out:
# (410, 775)
# (<Figure size 432x288 with 1 Axes>,
# ...
#  (-0.5, 774.5, 409.5, -0.5))

# %% [markdown]
# ###  harris corner detection

# %%
dst = cv2.cornerHarris(img,blockSize=2,ksize=3,k=0.04)
plt.figure(),plt.imshow(dst,cmap="gray"),plt.axis("off")
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  (-0.5, 774.5, 409.5, -0.5))

# %%
dst = cv2.dilate(dst,None)
img[dst>0.2*dst.max()] = 1
plt.figure(),plt.imshow(dst,cmap="gray"),plt.axis("off")
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  (-0.5, 774.5, 409.5, -0.5))

# %% [markdown]
# #### Shi Tamsai Detection

# %%
img = cv2.imread("sudoku.png",0)
img = np.float32(img)
corners = cv2.goodFeaturesToTrack(img,100,0.01,10) #img, kaç köşe bulunsun,0.01 quality, 10 ise 2 köşe arasındaki min distance 
corners = np.int64(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),10,(125,125,125),cv2.FILLED)
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 774.5, 409.5, -0.5)
