# %%
import cv2
import matplotlib.pyplot as plt

# %%
#resmi içe aktar
img = cv2.imread("sudoku.png",0)

# %%
plt.figure(),plt.imshow(img,cmap="gray"),plt.axis("off"),plt.title("Orijinal")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x194b7f955e0>,
#  (-0.5, 774.5, 409.5, -0.5),
#  Text(0.5, 1.0, 'Orijinal'))

# %% [markdown]
# ## X gradyan
#
# ### Ksize (Kernel Size) must be odd and not largen than 31

# %%
sobelx = cv2.Sobel(img, ddepth= cv2.CV_16S,dx=1,dy=0,ksize=5)
plt.figure(),plt.imshow(sobelx,cmap="gray"),plt.axis("off"),plt.title("SOBEL X")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x194b9acca90>,
#  (-0.5, 774.5, 409.5, -0.5),
#  Text(0.5, 1.0, 'SOBEL X'))

# %% [markdown]
# ## Y Gradyan
#
# ### Ksize (Kernel Size) must be odd and not largen than 31

# %%
sobely = cv2.Sobel(img,ddepth = cv2.CV_16S, dx=0, dy=1,ksize=5)
plt.figure(),plt.imshow(sobely,cmap="gray"),plt.axis("off"),plt.title("SOBEL Y")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x194b91778b0>,
#  (-0.5, 774.5, 409.5, -0.5),
#  Text(0.5, 1.0, 'SOBEL Y'))

# %% [markdown]
# ## Laplacian Gradyan
#
# #### Ksize (Kernel size) must be odd and not larger than 31

# %%
laplacian = cv2.Laplacian(img, ddepth = cv2.CV_16S,ksize=11)
plt.figure(),plt.imshow(laplacian,cmap="gray"),plt.axis("off"),plt.title("Laplacian")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x194b916fd30>,
#  (-0.5, 774.5, 409.5, -0.5),
#  Text(0.5, 1.0, 'Laplacian'))
